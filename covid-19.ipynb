# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("C:\\Users\\Ujjwal\\Desktop\\covid-19.csv")

# %%
df
# Out:
#     Province/State         Country/Region        Lat       Long  1/22/20  \
# 0              NaN            Afghanistan  33.000000  65.000000        0
# 1              NaN                Albania  41.153300  20.168300        0
# 2              NaN                Algeria  28.033900   1.659600        0
# 3              NaN                Andorra  42.506300   1.521800        0
# 4              NaN                 Angola -11.202700  17.873900        0
# ..             ...                    ...        ...        ...      ...
# 261            NaN  Sao Tome and Principe   0.186360   6.613081        0
# 262            NaN                  Yemen  15.552727  48.516388        0
# 263            NaN                Comoros -11.645500  43.333300        0
# 264            NaN             Tajikistan  38.861034  71.276093        0
# 265            NaN                Lesotho -29.609988  28.233608        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  6/22/20  6/23/20  \
# ...

# %%
import seaborn as sns

# %%
df.head(10)
# Out:
#                  Province/State       Country/Region      Lat      Long  \
# 0                           NaN          Afghanistan  33.0000   65.0000
# 1                           NaN              Albania  41.1533   20.1683
# 2                           NaN              Algeria  28.0339    1.6596
# 3                           NaN              Andorra  42.5063    1.5218
# 4                           NaN               Angola -11.2027   17.8739
# 5                           NaN  Antigua and Barbuda  17.0608  -61.7964
# 6                           NaN            Argentina -38.4161  -63.6167
# 7                           NaN              Armenia  40.0691   45.0382
# 8  Australian Capital Territory            Australia -35.4735  149.0124
# 9               New South Wales            Australia -33.8688  151.2093
#
#    1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  6/22/20  \
# 0        0        0        0        0        0        0  ...    29157
# ...

# %%
df.shape
# Out:
# (266, 166)

# %%
df.drop(["Lat","Long"], axis=1,inplace=True)

# %%
df
# Out:
#     Province/State         Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  \
# 0              NaN            Afghanistan        0        0        0        0
# 1              NaN                Albania        0        0        0        0
# 2              NaN                Algeria        0        0        0        0
# 3              NaN                Andorra        0        0        0        0
# 4              NaN                 Angola        0        0        0        0
# ..             ...                    ...      ...      ...      ...      ...
# 261            NaN  Sao Tome and Principe        0        0        0        0
# 262            NaN                  Yemen        0        0        0        0
# 263            NaN                Comoros        0        0        0        0
# 264            NaN             Tajikistan        0        0        0        0
# 265            NaN                Lesotho        0        0        0        0
#
# ...

# %%
df_aggregated = df.groupby("Country/Region").sum()

# %%
df_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  6/22/20  6/23/20  6/24/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...    29157    29481    29640
# Albania               0        0        0  ...     1995     2047     2114
# Algeria               0        0        0  ...    11920    12076    12248
# Andorra               0        0        0  ...      855      855      855
# ...

# %%
df.shape
# Out:
# (266, 164)

# %%
df_aggregated.loc['India'].plot()
df_aggregated.loc['Spain'].plot()
df_aggregated.loc['China'].plot()
df_aggregated.loc['Italy'].plot()
df_aggregated.loc['Australia'].plot()
df_aggregated.loc['US'].plot()
plt.legend()

# %%
df_aggregated.loc['India'].plot()

# %%
df_aggregated.loc["India"].diff().plot()

# %%
df_aggregated.loc["India"].diff().max()
# Out:
# 19906.0

# %%
df_aggregated.loc["Italy"].diff().max()
# Out:
# 6557.0

# %%
df_aggregated.loc["China"].diff().max()
# Out:
# 15136.0

# %%
df_aggregated.loc["China"].diff().plot()

# %%
df_aggregated.loc["Italy"].diff().plot()

# %%
df_aggregated.loc["US"].diff().plot()

# %%
df_aggregated.loc["US"].diff().max()
# Out:
# 50655.0

# %%
countries = list(df_aggregated.index)
max_infection_rate = []
for Country in countries :
    max_infection_rate.append(df_aggregated.loc[Country].diff().max())
df_aggregated["max infection rate"] = max_infection_rate

# %%
df_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  6/23/20  6/24/20  6/25/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...    29481    29640    30175
# Albania               0        0        0  ...     2047     2114     2192
# Algeria               0        0        0  ...    12076    12248    12445
# Andorra               0        0        0  ...      855      855      855
# ...

# %%
corona_data = pd.DataFrame(df_aggregated["max infection rate"])
corona_data
# Out:
#                     max infection rate
# Country/Region
# Afghanistan                      915.0
# Albania                           82.0
# Algeria                          365.0
# Andorra                           79.0
# Angola                            47.0
# ...                                ...
# West Bank and Gaza               330.0
# Western Sahara                     4.0
# Yemen                            116.0
# Zambia                           208.0
# Zimbabwe                          76.0
#
# [188 rows x 1 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Columns: 164 entries, Province/State to 7/1/20
# dtypes: int64(162), object(2)
# memory usage: 340.9+ KB
